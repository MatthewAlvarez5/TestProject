# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewAlvarez5/TestProject/blob/master/CSCI164_Transformers_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
from IPython.display import Image

# %%
# file 1
# https://drive.google.com/file/d/17-sknYuqJJa2qE_xfrVGpp3OhEEu_NGg/view?usp=sharing
# !gdown 17-sknYuqJJa2qE_xfrVGpp3OhEEu_NGg
file_name1 = "CAT.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17-sknYuqJJa2qE_xfrVGpp3OhEEu_NGg
# To: /content/CAT.jpg
# 100% 183k/183k [00:00<00:00, 67.7MB/s]

# %%
# file 2
# https://drive.google.com/file/d/1Dm6crkVkre08owBWGl_d-gs9Y9X9tda3/view?usp=sharing
# !gdown 1Dm6crkVkre08owBWGl_d-gs9Y9X9tda3
file_name2 = "BrickWall.JPG"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Dm6crkVkre08owBWGl_d-gs9Y9X9tda3
# To: /content/BrickWall.JPG
# 100% 237k/237k [00:00<00:00, 97.3MB/s]

# %%
# file 3
#https://drive.google.com/file/d/1e05Hw-Ihm9WcqzKmfsf0IzAUh4dCOT39/view?usp=sharing
# !gdown 1e05Hw-Ihm9WcqzKmfsf0IzAUh4dCOT39
file_name3 = "DogMess.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1e05Hw-Ihm9WcqzKmfsf0IzAUh4dCOT39
# To: /content/DogMess.png
# 100% 1.18M/1.18M [00:00<00:00, 117MB/s]

# %%
### Task: Image captioning
captioner = pipeline(task="image-to-text",
                     model="nlpconnect/vit-gpt2-image-captioning")
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
captioner2 = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")

# %%
captioner3 = pipeline("image-to-text", model="microsoft/git-base")
# Out:
# config.json:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/707M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/503 [00:00<?, ?B/s]

# %% [markdown]
# # Photo 1

# %%
print(captioner('CAT.jpg'))
display(Image(filename='CAT.jpg'))
# Out:
# [{'generated_text': 'a black cat sitting in a garden '}]

# %% [markdown]
# # Photo 2

# %%
print(captioner2('DogMess.png'))
display(Image(filename='DogMess.png'))
# Out:
# [{'generated_text': 'a dog standing on a wooden floor with a pile of trash'}]

# %% [markdown]
# # Photo 3

# %%
print(captioner3('BrickWall.JPG'))
display(Image(filename='BrickWall.JPG'))
# Out:
# [{'generated_text': 'a man pointing at a brick wall'}]
